# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\itsas\Downloads\dataset-main\dataset-main\dataset_Facebook.csv",sep=";")

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df.head(6)
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
# 5            139441  Status         2          12             1          9
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
# ...

# %%
df.shape
# Out:
# (500, 19)

# %%
df.tail()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 495   0.0                       4684                             7536
# 496   0.0                       3480                             6229
# 497   0.0                       3778                             7216
# 498   0.0                       4156                             7564
# 499   NaN                       4188                             7292
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df.iloc[[0,5]]
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 5            139441  Status         2          12             1          9
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 5   0.0                      10472                            20849
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                     178                      109
# 5                    1191                     1073
#
#    Lifetime Post Consumptions  \
# 0                         159
# 5                        1389
#
#    Lifetime Post Impressions by people who have liked your Page  \
# 0                                               3078
# 5                                              16034
#
#    Lifetime Post reach by people who like your Page  \
# ...

# %%
df1 = pd.DataFrame({ #creating new dataframe
    "city":["new york", "delhi" , "mumbai" , "chicago"],
    "temperature":[21,55,48, 11],
})
df1
# Out:
#        city  temperature
# 0  new york           21
# 1     delhi           55
# 2    mumbai           48
# 3   chicago           11

# %%
df2 = pd.DataFrame({
    "city":["new york", "delhi", "mumbai", "chicago"],
    "humidity":[65,68,75,55]
})
df2
# Out:
#        city  humidity
# 0  new york        65
# 1     delhi        68
# 2    mumbai        75
# 3   chicago        55

# %%
df3 = pd.merge(df1, df2, on="city") #here we are using the merge function to merge two dataframes
df3
# Out:
#        city  temperature  humidity
# 0  new york           21        65
# 1     delhi           55        68
# 2    mumbai           48        75
# 3   chicago           11        55

# %%
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando", "baltimore"],
    "temperature": [21,14,35, 38],
})
df1
# Out:
#         city  temperature
# 0   new york           21
# 1    chicago           14
# 2    orlando           35
# 3  baltimore           38

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","san diego"],
    "humidity": [65,68,71],
})
df2
# Out:
#         city  humidity
# 0    chicago        65
# 1   new york        68
# 2  san diego        71

# %%
df3=pd.merge(df1,df2,on="city",how="inner") # just like in databases there are joins - here the inner join will add only the common elements whcih is intersection
df3
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65

# %%
df3=pd.merge(df1,df2,on="city",how="outer") # just like in databases there are joins - here the outer join will add all the elements which is union 
df3
# Out:
#         city  temperature  humidity
# 0   new york         21.0      68.0
# 1    chicago         14.0      65.0
# 2    orlando         35.0       NaN
# 3  baltimore         38.0       NaN
# 4  san diego          NaN      71.0

# %%
df3=pd.merge(df1,df2,on="city",how="left") # just like in databases there are joins - here the left join will take the common elements as well as the data from left table
df3
# Out:
#         city  temperature  humidity
# 0   new york           21      68.0
# 1    chicago           14      65.0
# 2    orlando           35       NaN
# 3  baltimore           38       NaN

# %%
df3=pd.merge(df1,df2,on="city",how="right") # just like in databases there are joins - here the right join will take the common elements as well as the data from right table
df3
# Out:
#         city  temperature  humidity
# 0    chicago         14.0        65
# 1   new york         21.0        68
# 2  san diego          NaN        71

# %%
df1.sort_values("city")
# Out:
#         city  temperature
# 3  baltimore           38
# 1    chicago           14
# 0   new york           21
# 2    orlando           35

# %%
df1.sort_values("city", ascending=False)
# Out:
#         city  temperature
# 2    orlando           35
# 0   new york           21
# 1    chicago           14
# 3  baltimore           38

# %%
df1.sort_values(["city", "temperature"])
# Out:
#         city  temperature
# 3  baltimore           38
# 1    chicago           14
# 0   new york           21
# 2    orlando           35

# %%
transposed_df = df1.transpose()

# %%
transposed_df
# Out:
#                     0        1        2          3
# city         new york  chicago  orlando  baltimore
# temperature        21       14       35         38

# %%
stacked_df = df1.stack() # this is also used to transpose data
df1
# Out:
#         city  temperature
# 0   new york           21
# 1    chicago           14
# 2    orlando           35
# 3  baltimore           38

# %%
df1
# Out:
#         city  temperature
# 0   new york           21
# 1    chicago           14
# 2    orlando           35
# 3  baltimore           38

# %%
pivot_df = df1.pivot(index="city", columns="temperature")
# we can use pivot to specify and reshape our table
pivot_df
# Out:
# Empty DataFrame
# Columns: []
# Index: [baltimore, chicago, new york, orlando]

# %%
melted_df = pd.melt(df1, id_vars=["city"])
#melt also helps us in data reshaping in id_vars specify the name of the column you want to keep intact
melted_df
# Out:
#         city     variable  value
# 0   new york  temperature     21
# 1    chicago  temperature     14
# 2    orlando  temperature     35
# 3  baltimore  temperature     38

# %%
melted_df = pd.melt(df1, id_vars=["city"] ,var_name='temp', value_name='temp_value') 
#melt also helps us in data reshaping
melted_df
# Out:
#         city         temp  temp_value
# 0   new york  temperature          21
# 1    chicago  temperature          14
# 2    orlando  temperature          35
# 3  baltimore  temperature          38
